# %%
import matplotlib.pyplot as plt
import numpy as np
from astropy.io import fits
from mpl_toolkits.axes_grid1 import make_axes_locatable

## only need the nu_spec module
import nu_spec

## to fit the model
from scipy.optimize import minimize

## for MCMC
import emcee
import corner

# %matplotlib notebook

# %% [markdown]
# # Read in .pha file, create spectrum, compare with XSPEC

# %%
d_pha = 'spectralData/'
f_pha = 'nu80415201001A06_chu2_S_cl_grade0_sr.pha'
channel, channel_error, counts, counts_error = nu_spec.nustar_ctsSpec(d_pha+f_pha)

# %%
fig = plt.figure(figsize=(5,7))
ax = fig.gca()
ax.tick_params(axis='both', which='both', direction='in')

## plot spectrum created from Python
plt.errorbar(channel, 
             counts, 
             xerr=channel_error, 
             yerr=counts_error, 
             color='k', 
             fmt='.',
             markersize=0.01)
ax.set_xlim([2,10])
ax.set_ylim([0.1,3500])
ax.set_title('NuSTAR - XSPEC check and Python')
ax.set_ylabel('Count s$^{-1}$ keV$^{-1}$')
ax.set_yscale('log')
ax.set_xlabel('Energy [keV]')

plt.show()

# %% [markdown]
# # Read in .arf file

# %%
d_arf = 'spectralData/'
f_arf = 'nu80415201001A06_chu2_S_cl_grade0_sr.arf'
e_lo, e_hi, eff_area = nu_spec.read_arf(d_arf+f_arf)
e_mid = (e_hi + e_lo)/2 ## same as channel above

# %%
fig = plt.figure()

plt.plot(e_mid, eff_area,drawstyle='steps-mid')
plt.xlim([1.6,10])
plt.title('NuSTAR - Effective area [cm$^{2}$]')
plt.ylabel('Response [cm$^{2}$]')
plt.xlabel('Energy [keV]')
plt.yscale('log')
plt.show()

# %% [markdown]
# # Read in .rmf file

# %%
d_rmf = 'spectralData/'
f_rmf = 'nu80415201001A06_chu2_S_cl_grade0_sr.rmf'
e_lo, e_hi, ngrp, fchan, nchan, matrix = nu_spec.read_rmf(d_rmf+f_rmf)

# %%
fchan_array = nu_spec.col2arr_py(fchan)
nchan_array = nu_spec.col2arr_py(nchan)

# %%
mat_array = nu_spec.vrmf2arr_py(data=matrix,  
                                n_grp_list=ngrp,
                                f_chan_array=fchan_array, 
                                n_chan_array=nchan_array)

# %%
from matplotlib.colors import Normalize

fig,axs = plt.subplots(1,1, sharex=True, sharey=True, figsize=(10,4))

# Redistribution matrix [counts per photon]
## Python rdm
axs.imshow(mat_array, aspect=1, origin='lower', norm=Normalize(vmin=0,vmax=0.00005))
axs.set_title('Python Redistribution Matrix')
axs.set_ylabel('Energy')
axs.set_xlabel('Channels')
plt.show()

# %% [markdown]
# # Total Spectral Response SRM = rmf*arf [counts per photon * cm ^2]

# %%
srm = nu_spec.make_srm(rmf_matrix=mat_array, arf_array=eff_area)

# %%
from matplotlib.colors import LogNorm

fig,axs = plt.subplots(1,1, sharex=True, sharey=True, figsize=(10,4))
axs.imshow(srm, aspect=len(srm[0,:])/channel[-1], origin='lower', norm=Normalize(vmax=0.0005), extent=[0, len(srm[0,:]), channel[0], channel[-1]])
axs.set_title('Python Spectral Response Matrix')
axs.set_ylabel('Energy')
axs.set_xlabel('Channels')
plt.show()

# %% [markdown]
# # Define some models to fit

# %%
def test_model_powerlaw(energies, constant, power):
    return constant*np.array(energies, dtype=float)**-power

# constant is [photon s^-1 keV^-1 cm^-2]
# power is the spectral index

# %%
def test_model_brokenpowerlaw(energies, constant, power1, brk, power2):
    model_spec = []
    for e in energies:
        if e < brk:
            model_spec.append(constant*e**(-power1))
        else:
            model_spec.append(constant*e**(power2-power1)*e**(-power2))
    return model_spec

# %% [markdown]
# ## Get modelled counts spectrum

# %% [markdown]
# Have how the physical photon (y-axis) is converted and sorted into the actual detector channels (x-axis) - Spec Resp
#
# Find the number of photons at each energy (photon spectrum) and multiply each energy seen by the number of photons for
# For that energy range to get a 2D matrix of the counts produced by one energy across several detector channels.
#
# Sum the columns (total counts seen by the detector from multiple energy ranges) to get the observed count spectrum

# %%
fig,axs = plt.subplots(1,3, sharex=True, figsize=(14,4))
axs[0].plot(channel, 
            test_model_powerlaw(channel, 20**10, 15))
axs[0].set_title('Model Photon Spetrum')
axs[0].set_xlabel('Energy [keV]')
axs[0].set_ylabel('Photon Spectrum [ph s$^{-1}$ cm $^{-2}$ keV$^{-1}$]')
axs[0].set_xlim([1.6,10])

axs[1].plot(channel, 
            nu_spec.make_model(channel, test_model_powerlaw, parameters=[20**4, 10], srm=srm))
axs[1].set_title('Model Count Spetrum')
axs[1].set_xlabel('Energy [keV]')
axs[1].set_ylabel('Count Spectrum [cts s$^{-1}$ keV$^{-1}$]')
axs[1].set_ylim([1.,3000])
axs[1].set_yscale('log')

axs[2].errorbar(channel, 
             counts, 
             xerr=channel_error, 
             yerr=counts_error, 
             color='k', 
             fmt='.',
             markersize=0.01)
axs[2].set_title('Observed Count Spetrum')
axs[2].set_xlabel('Energy [keV]')
axs[2].set_ylabel('Count Spectrum [cts s$^{-1}$ keV$^{-1}$]')
axs[2].set_ylim([1.,3000])
axs[2].set_yscale('log')

plt.show()

# %% [markdown]
# ## Non-Linear Least squares Fitting

# %% [markdown]
# # Try Maximum likelihood approach too

# %% [markdown]
# ## Likelihood

# %%
def minus_log_poisson_likelihood(mod_const_and_power, obs_counts, channel, total_response):
    # allow the model to be varied to minimize -ln(L)
    
    mu = nu_spec.make_model(channel, 
                    test_model_powerlaw, 
                    [mod_const_and_power[0], mod_const_and_power[1]], 
                    total_response)
    
    # mu number of counts predicted
    # x is the number of counts
    likelihoods = []
    for i in range(len(obs_counts)):
        l = obs_counts[i]*( np.log(mu[i]/obs_counts[i]) + 1 ) - mu[i]
        l = l if np.isfinite(l) else 0 ## if there are no counts, I don't want it to affect the result
        likelihoods.append(l)
    return -np.sum(likelihoods)

# %% [markdown]
# # Maximise the Likelihood

# %%
initial = [20**4, 10]
methods = [None, 'Nelder-Mead', 'Powell', 'CG', 'BFGS', 'L-BFGS-B', 'COBYLA', 'TNC', 'SLSQP'] 
method = methods[1]
# L-BFGS-B and COBYLA change the fit the most compared to the others
soln = minimize(minus_log_poisson_likelihood, initial, args=(counts[:75], channel[:75], srm), method=method)

# %% [markdown]
# # Work out residuals of Max. Likelihood fit to get Chi^2

# %%
# maximum likelihood
model_cts_minimize = nu_spec.make_model(channel, test_model_powerlaw, [*soln.x], srm)
res_lh = [(counts[i] - model_cts_minimize[i])/counts_error[i] if counts_error[i]>0 else 0 for i in range(len(counts_error))]
print('Constant and power law: ', soln.x)
print('Minimized log(L): ', minus_log_poisson_likelihood(soln.x, counts[:75], channel[:75], srm))
print('Chi^2 from Minimized log(L): ', np.sum(np.array(res_lh)**2))
# Out:
# Constant and power law:  [1.48564368e+06 1.06274450e+01]
# Minimized log(L):  14181.551857723587
# Chi^2 from Minimized log(L):  14966.197240874493

# %% [markdown]
# # Plot results

# %%
fig, axs = plt.subplots(figsize=(5,7))
## plot fits
axs.plot(channel, model_cts_minimize, label=str(method)+' Method LH Fit Model', color='c')
axs.set_title('Model Count Spetrum')
axs.set_xlabel('Energy [keV]')
axs.set_ylabel('Count Spectrum [cts s$^{-1}$ keV$^{-1}$]')
axs.set_ylim([0.1,3500])
axs.set_yscale('log')
axs.xaxis.set_tick_params(labelbottom=False)
axs.get_xaxis().set_visible(False)

## plot data
axs.errorbar(channel, counts,xerr=channel_error, yerr=counts_error, color='k', fmt='.',markersize=0.01, label='Data')
plt.legend()

#residuals plotting
divider = make_axes_locatable(axs)
res = divider.append_axes('bottom', 1.2, pad=0.2, sharex=axs)
res.plot(channel, res_lh, drawstyle='steps-mid', color='c')
res.axhline(0, linestyle=':', color='k')
res.set_xlim([2,10])
res.set_ylim([-7,7])
res.set_ylabel('(y$_{Data}$ - y$_{Model}$)/$\sigma_{Error}$')

axs.set_xlim([2,10])
plt.show()

# %% [markdown]
# # MCMC Maximum likelihood result it

# %%
def prior(constant, power):
    if 20**3 < constant <20**7 and 0.1 < power < 11:
        return 0.0
    return -np.inf

# %%
def prob(mod_const_and_power, obs_counts, channel, total_response):
    lp = prior(*mod_const_and_power)
    if not np.isfinite(lp):
        return -np.inf
    ## 'lp -' as its the negative log
    return lp - minus_log_poisson_likelihood(mod_const_and_power, obs_counts, channel, total_response)

# %%
ndim, nwalkers = 2, 10000
pos = [soln["x"] + [1000*np.random.randn(1)[0], 0.1*np.random.randn(1)[0]] for i in range(nwalkers)]

# %%
sampler = emcee.EnsembleSampler(nwalkers, ndim, prob, args=(counts[:75], channel[:75], srm))
sampler.run_mcmc(pos, 500, progress=True);
# Out:
#   2%|▏         | 9/500 [01:33<1:25:21, 10.43s/it]Traceback (most recent call last):
#   File "/anaconda3/lib/python3.7/site-packages/emcee/ensemble.py", line 545, in __call__
#     return self.f(x, *self.args, **self.kwargs)
#   File "<ipython-input-32-64a9a70910d9>", line 6, in prob
#     return lp - minus_log_poisson_likelihood(mod_const_and_power, obs_counts, channel, total_response)
#   File "<ipython-input-25-ee80d77c843b>", line 7, in minus_log_poisson_likelihood
#     total_response)
#   File "/Users/kris/Documents/PhD/data/nustar/nustarFittingExample/nu_spec.py", line 450, in make_model
#     model_cts_matrix = np.array([srm[r, :] * photon_spec[r] for r in range(len(photon_spec))])
#   File "/Users/kris/Documents/PhD/data/nustar/nustarFittingExample/nu_spec.py", line 450, in <listcomp>
#     model_cts_matrix = np.array([srm[r, :] * photon_spec[r] for r in range(len(photon_spec))])
# KeyboardInterrupt
#   2%|▏         | 9/500 [01:37<1:28:44, 10.84s/it]
# emcee: Exception while calling your likelihood function:
#   params: [1.49522995e+06 1.06391565e+01]
#   args: (array([1017.83288867,  697.73703322,  854.78780874, 1025.02605396,
#        1148.50872479, 1262.40050856, 1422.44843629, 1475.19831509,
#        1576.5020596 , 1722.16365674, 1963.13469399, 2033.26805558,
#        2141.16553494, 2341.37530221, 2415.10524644, 2383.93486351,
#        2431.28986834, 2392.32688968, 2406.71322027, 2324.59124986,
#        2170.53762655, 2053.04926013, 1898.99563681, 1730.55568292,
#        1593.28611195, 1475.19831509, 1342.72418765, 1299.5651959 ,
#        1240.22158225, 1171.88651198, 1165.89220758, 1141.91498994,
#        1073.57991968, 1002.24769721,  938.70807047,  827.8134389 ,
#         800.23963862,  781.65729495,  666.5666503 ,  634.79683693,
#         549.07828388,  509.51587478,  493.93068331,  425.59561305,
#         407.01326938,  383.63548218,  362.65541675,  292.52205517,
#         269.14426797,  273.9397115 ,  251.16135474,  244.56761989,
#         193.01660197,  228.38299799,  188.22115845,  176.83198007,
#         155.2524842 ,  139.66729273,  116.28950554,  113.29235333,
#         104.90032716,   88.11627481,   76.127666  ,   79.72424864,
#          71.33222247,   55.14760056,   52.15044836,   38.96297866,
#          44.95728307,   40.16183954,   38.96297866,   37.16468734,
#          39.5624091 ,   32.36924381,   28.77266116]), array([1.62, 1.66, 1.7 , 1.74, 1.78, 1.82, 1.86, 1.9 , 1.94, 1.98, 2.02,
#        2.06, 2.1 , 2.14, 2.18, 2.22, 2.26, 2.3 , 2.34, 2.38, 2.42, 2.46,
#        2.5 , 2.54, 2.58, 2.62, 2.66, 2.7 , 2.74, 2.78, 2.82, 2.86, 2.9 ,
#        2.94, 2.98, 3.02, 3.06, 3.1 , 3.14, 3.18, 3.22, 3.26, 3.3 , 3.34,
#        3.38, 3.42, 3.46, 3.5 , 3.54, 3.58, 3.62, 3.66, 3.7 , 3.74, 3.78,
#        3.82, 3.86, 3.9 , 3.94, 3.98, 4.02, 4.06, 4.1 , 4.14, 4.18, 4.22,
#        4.26, 4.3 , 4.34, 4.38, 4.42, 4.46, 4.5 , 4.54, 4.58]), array([[3.20262790e-05, 1.06749940e-04, 2.38402408e-04, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [4.38876267e-05, 1.99917205e-04, 4.24209952e-04, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [7.33246711e-05, 2.39959678e-04, 5.66563217e-04, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00]]))
#   kwargs: {}
#   exception:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-ef4c0af005a1> in <module>
#       1 sampler = emcee.EnsembleSampler(nwalkers, ndim, prob, args=(counts[:75], channel[:75], srm))
# ----> 2 sampler.run_mcmc(pos, 500, progress=True);
#
# /anaconda3/lib/python3.7/site-packages/emcee/ensemble.py in run_mcmc(self, initial_state, nsteps, **kwargs)
#     382
#     383         results = None
# --> 384         for results in self.sample(initial_state, iterations=nsteps, **kwargs):
#     385             pass
#     386
#
# /anaconda3/lib/python3.7/site-packages/emcee/ensemble.py in sample(self, initial_state, log_prob0, rstate0, blobs0, iterations, tune, skip_initial_state_check, thin_by, thin, store, progress)
#     341
#     342                     # Propose
# --> 343                     state, accepted = move.propose(model, state)
#     344                     state.random_state = self.random_state
#     345
#
# /anaconda3/lib/python3.7/site-packages/emcee/moves/red_blue.py in propose(self, model, state)
#      91
#      92             # Compute the lnprobs of the proposed position.
# ---> 93             new_log_probs, new_blobs = model.compute_log_prob_fn(q)
#      94
#      95             # Loop over the walkers and update them accordingly.
#
# /anaconda3/lib/python3.7/site-packages/emcee/ensemble.py in compute_log_prob(self, coords)
#     425                 map_func = map
#     426             results = list(
# --> 427                 map_func(self.log_prob_fn, (p[i] for i in range(len(p))))
#     428             )
#     429
#
# /anaconda3/lib/python3.7/site-packages/emcee/ensemble.py in __call__(self, x)
#     543     def __call__(self, x):
#     544         try:
# --> 545             return self.f(x, *self.args, **self.kwargs)
#     546         except:  # pragma: no cover
#     547             import traceback
#
# <ipython-input-32-64a9a70910d9> in prob(mod_const_and_power, obs_counts, channel, total_response)
#       4         return -np.inf
#       5     ## 'lp -' as its the negative log
# ----> 6     return lp - minus_log_poisson_likelihood(mod_const_and_power, obs_counts, channel, total_response)
#
# <ipython-input-25-ee80d77c843b> in minus_log_poisson_likelihood(mod_const_and_power, obs_counts, channel, total_response)
#       5                     test_model_powerlaw,
#       6                     [mod_const_and_power[0], mod_const_and_power[1]],
# ----> 7                     total_response)
#       8
#       9     # mu number of counts predicted
#
# ~/Documents/PhD/data/nustar/nustarFittingExample/nu_spec.py in make_model(energies, photon_model, parameters, srm)
#     448         photon_spec = photon_model(energies, *parameters)
#     449
# --> 450     model_cts_matrix = np.array([srm[r, :] * photon_spec[r] for r in range(len(photon_spec))])
#     451     model_cts_spectrum = model_cts_matrix.sum(axis=0) # sum the rows together
#     452
#
# ~/Documents/PhD/data/nustar/nustarFittingExample/nu_spec.py in <listcomp>(.0)
#     448         photon_spec = photon_model(energies, *parameters)
#     449
# --> 450     model_cts_matrix = np.array([srm[r, :] * photon_spec[r] for r in range(len(photon_spec))])
#     451     model_cts_spectrum = model_cts_matrix.sum(axis=0) # sum the rows together
#     452
#
# KeyboardInterrupt:

# %% [markdown]
# # Get corner plot of the MCMC

# %%
samples = sampler.chain[:, 50:, :].reshape((-1, ndim))

# %%
fig = corner.corner(samples, labels=["Constant", "Power"])

# %%
fig,axs = plt.subplots(figsize=(5,7))

# get residuals for all the trys
for_ress = []
for constant, power in samples[np.random.randint(len(samples), size=100)]:
    model_cts_try = nu_spec.make_model(channel, test_model_powerlaw, [constant, power], srm)
    for_ress.append(model_cts_try)
    plt.plot(channel, model_cts_try, color="k", alpha=0.1)

# plot the maximised likelihood solution
axs.plot(channel, model_cts_minimize, label=str(method)+' Method LH Fit Model', color='c')
axs.set_title('Model Count Spetrum')
axs.set_xlabel('Energy [keV]')
axs.set_ylabel('Count Spectrum [cts s$^{-1}$ keV$^{-1}$]')
axs.set_ylim([1,300])
axs.set_yscale('log')
axs.xaxis.set_tick_params(labelbottom=False)
axs.get_xaxis().set_visible(False)

# plot data
axs.errorbar(channel, counts,xerr=channel_error, yerr=counts_error, color='k', fmt='.',markersize=0.01, label='Data')
axs.axvline(x=2.5, c='k', linestyle='--')
plt.legend()

#residuals plotting
divider = make_axes_locatable(axs)
res = divider.append_axes('bottom', 1.2, pad=0.2, sharex=axs)
for m in for_ress:
    r = [(counts[i] - m[i])/counts_error[i] if counts_error[i]>0 else 0 for i in range(len(counts_error))]
    res.plot(channel, r, drawstyle='steps-mid', color='k', alpha=0.1)
res.plot(channel, res_lh, drawstyle='steps-mid', color='c')
res.axhline(0, linestyle=':', color='k')
res.set_xlim([2,10])
res.set_ylim([-5,5])

res.set_ylabel('(y$_{Data}$ - y$_{Model}$)/$\sigma_{Error}$')

#fig.text(.5, .05, txt, ha='center')
axs.set_xlim([2,10])
plt.show()
